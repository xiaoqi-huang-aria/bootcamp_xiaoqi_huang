# %% [markdown]
# # Homework Starter — Stage 03: Python Fundamentals
#
# ## Instructions
# Fill in the cells below to complete your homework. Refer to lecture examples.

# %%
# --- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## 1. NumPy Operations

# %%
# TODO: Create a NumPy array and perform vectorized operations

arr = np.array([1, 2, 3, 4, 5])
result = arr * 2

# %% [markdown]
# ## 2. Compare Loop vs Vectorization

# %%
# TODO: Compare speed using %timeit
# %timeit arr * 2
# %timeit [x * 2 for x in arr]
# Out:
# 589 ns ± 17.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 806 ns ± 13.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## 3. Load and Inspect Dataset

# %%
# TODO: Load CSV and inspect with .head(), .info(), .describe()
df = pd.read_csv('data/raw/starter_data.csv')
df.head(), df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  10 non-null     object
#  1   value     10 non-null     int64
#  2   date      10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes
# (  category  value        date
#  0        A     10  2025-08-01
#  1        B     15  2025-08-02
#  2        A     12  2025-08-03
#  3        B     18  2025-08-04
#  4        C     25  2025-08-05,
#  None,
#             value
#  count  10.000000
#  mean   17.600000
#  std     7.381659
#  min    10.000000
#  25%    12.250000
#  50%    14.500000
#  75%    23.250000
#  max    30.000000)

# %% [markdown]
# ## 4. Summary Statistics and Groupby

# %%
# TODO: Perform groupby and save output to data/processed/
summary = df.groupby('category').mean(numeric_only=True).reset_index()
os.makedirs('data/processed', exist_ok=True)
summary.to_csv('data/processed/summary.csv', index=False)
summary
# Out:
#   category      value
# 0        A  11.500000
# 1        B  15.666667
# 2        C  27.666667

# %%
df['value'].hist()
plt.savefig('data/processed/histogram.png')
