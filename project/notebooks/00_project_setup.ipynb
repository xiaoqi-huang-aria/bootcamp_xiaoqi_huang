# %% [markdown]
# # Environment & Config Check

# %%
import sys
print("Python:", sys.version)
print("Path:", sys.executable)
# Out:
# Python: 3.11.15 (main, Jun 11 2026, 15:14:57) [Clang 20.1.8 ]
# Path: /opt/anaconda3/envs/fe-course/bin/python

# %%
from src.config import load_env
load_env()
# Out:
# True

# %%
import os
from pathlib import Path
from src.config import get_key, get_data_dir

print("API_KEY present:", get_key("API_KEY") is not None)
print("Data directory:", get_data_dir())
# Out:
# API_KEY present: True
# Data directory: /Users/xiaoqihuang/bootcamp_xiaoqi_huang/project/data

# %%
import numpy as np

values = np.array([1, 2, 3, 4, 5])
scaled = values * 10

print("Array:", values)
print("Mean:", values.mean())
print("Vectorized * 10:", scaled)
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]
